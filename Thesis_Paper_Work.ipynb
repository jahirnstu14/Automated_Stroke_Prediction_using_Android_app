# %% [markdown]
# <a href="https://colab.research.google.com/github/jahirnstu14/Automated_Stroke_Prediction_using_Android_app/blob/main/Thesis_Paper_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
dataset.shape
# Out:
# (5110, 12)

# %%
dataset
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
print(dataset.dtypes)
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
dataset.bmi.replace(to_replace=np.nan, value=dataset.bmi.mean(), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
dataset.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# ...

# %%
corr_matrix = dataset.corr()
corr_matrix['stroke'].sort_values(ascending=False)
# Out:
# <ipython-input-11-e1100981c073>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = dataset.corr()
# stroke               1.000000
# age                  0.245257
# heart_disease        0.134914
# avg_glucose_level    0.131945
# hypertension         0.127904
# bmi                  0.038947
# id                   0.006388
# Name: stroke, dtype: float64

# %% [markdown]
# ##data visualization

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Assuming 'dataset' is your DataFrame containing the data
# fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Create a figure with two subplots

# # Plot distribution plot
# sns.distplot(dataset.bmi, color="red", label="bmi", kde=True, ax=axes[0])
# axes[0].set_title('Distribution Plot')
# axes[0].legend()

# # Plot box plot
# sns.boxplot(data=dataset.bmi, color="red", orient='h', ax=axes[1])
# axes[1].set_title('Box Plot')

# plt.show()
# dataset['bmi'].describe()

# %%
# dataset['bmi'].skew()

# %%
# percentile25 = dataset['bmi'].quantile(0.25)
# percentile75 = dataset['bmi'].quantile(0.75)
# print(percentile25)
# # print(percentile75)

# %%
# iqr = percentile75 - percentile25

# %%
# upper_limit = percentile75 + 1.5 * iqr
# lower_limit = percentile25 - 1.5 * iqr

# %%
# dataset[dataset['bmi']>upper_limit]

# %%
# dataset[dataset['bmi']<lower_limit]

# %%
# dataset['bmi'] = np.where(
#     dataset['bmi'] > upper_limit,
#     upper_limit,
#     np.where(
#         dataset['bmi'] < lower_limit,
#         lower_limit,
#         dataset['bmi']
#     )
# )

# # Number of outlier rows after capping:
# num_outliers_after = dataset[(dataset['bmi']>upper_limit) | (dataset['bmi']<lower_limit)].shape[0]
# print("Number of outlier rows after capping:", num_outliers_after)

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Assuming 'dataset' is your DataFrame containing the data
# fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Create a figure with two subplots

# # Plot distribution plot
# sns.distplot(dataset.bmi, color="red", label="bmi", kde=True, ax=axes[0])
# axes[0].set_title('Distribution Plot')
# axes[0].legend()

# # Plot box plot
# sns.boxplot(data=dataset.bmi, color="red", orient='h', ax=axes[1])
# axes[1].set_title('Box Plot')

# plt.show()

# %%
# dataset['bmi'].describe()

# %%
# Removing rows where the 'column_name' column contains "others"
dataset = dataset[dataset['gender'] != "Other"]

# %%
dataset
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
corr_matrix = dataset.corr()
corr_matrix['stroke'].sort_values(ascending=False)
# Out:
# <ipython-input-24-e1100981c073>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = dataset.corr()
# stroke               1.000000
# age                  0.245239
# heart_disease        0.134905
# avg_glucose_level    0.131991
# hypertension         0.127891
# bmi                  0.038912
# id                   0.006430
# Name: stroke, dtype: float64

# %% [markdown]
# To find the Input feature name optional

# %%
dataset= dataset.drop(columns=['id'])
dataset
#dataset.info()
X = dataset.drop(columns=['stroke'])  # Input features
Y = dataset['stroke']
X=pd.get_dummies(X,drop_first=True,columns=['gender','ever_married','work_type','Residence_type','smoking_status'])
X
# Out:
#        age  hypertension  heart_disease  avg_glucose_level        bmi  \
# 0     67.0             0              1             228.69  36.600000
# 1     61.0             0              0             202.21  28.893237
# 2     80.0             0              1             105.92  32.500000
# 3     49.0             0              0             171.23  34.400000
# 4     79.0             1              0             174.12  24.000000
# ...    ...           ...            ...                ...        ...
# 5105  80.0             1              0              83.75  28.893237
# 5106  81.0             0              0             125.20  40.000000
# 5107  35.0             0              0              82.99  30.600000
# 5108  51.0             0              0             166.29  25.600000
# 5109  44.0             0              0              85.28  26.200000
#
#       gender_Male  ever_married_Yes  work_type_Never_worked  \
# 0               1                 1                       0
# ...

# %%
x=X.to_numpy()
y=Y.to_numpy()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 0)

# %%
print("Number transactions x_train dataset: ", x_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions x_test dataset: ", x_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions x_train dataset:  (4087, 15)
# Number transactions y_train dataset:  (4087,)
# Number transactions x_test dataset:  (1022, 15)
# Number transactions y_test dataset:  (1022,)

# %%
from imblearn.over_sampling import SMOTE
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x_train_res, y_train_res = sm.fit_resample(x_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(x_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
# Out:
# Before OverSampling, counts of label '1': 195
# Before OverSampling, counts of label '0': 3892
#
# After OverSampling, the shape of train_X: (7784, 15)
# After OverSampling, the shape of train_y: (7784,)
#
# After OverSampling, counts of label '1': 3892
# After OverSampling, counts of label '0': 3892

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_res = scaler.fit_transform(x_train_res)
x_test= scaler.transform(x_test)

# %% [markdown]
# # **Model creating **

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, classification_report, roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score

# %%
model = LogisticRegression(C=1,random_state=2)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)  #Confusion Matrix
accuracies = cross_val_score(estimator = model, X = x_train_res, y = y_train_res, cv = 10)
print(classification_report(y_test, y_pred))
print('Accuracy Score: ',accuracy_score(y_test, y_pred))
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean()*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.86       968
#            1       0.15      0.72      0.25        54
#
#     accuracy                           0.77      1022
#    macro avg       0.56      0.75      0.55      1022
# weighted avg       0.94      0.77      0.83      1022
#
# Accuracy Score:  0.7661448140900196
# K-Fold Validation Mean Accuracy: 79.25 %

# %%
model = KNeighborsClassifier(metric='manhattan', n_neighbors=5)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       968
#            1       0.12      0.15      0.13        54
#
#     accuracy                           0.90      1022
#    macro avg       0.54      0.54      0.54      1022
# weighted avg       0.91      0.90      0.90      1022
#
# Accuracy Score: 0.8972602739726028
# K-Fold Validation Mean Accuracy: 95.75 %

# %%
model = SVC(C=1, kernel='linear', degree=3, gamma='auto',random_state=0)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.76      0.85       968
#            1       0.15      0.74      0.24        54
#
#     accuracy                           0.76      1022
#    macro avg       0.56      0.75      0.55      1022
# weighted avg       0.94      0.76      0.82      1022
#
# Accuracy Score: 0.7563600782778865
# K-Fold Validation Mean Accuracy: 79.32 %

# %%
model = DecisionTreeClassifier( criterion='entropy', random_state=0)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       968
#            1       0.08      0.09      0.09        54
#
#     accuracy                           0.90      1022
#    macro avg       0.52      0.52      0.52      1022
# weighted avg       0.90      0.90      0.90      1022
#
# Accuracy Score: 0.898238747553816
# K-Fold Validation Mean Accuracy: 94.88 %

# %%
model = RandomForestClassifier(criterion='gini', n_estimators= 10, random_state= 0)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       968
#            1       0.11      0.02      0.03        54
#
#     accuracy                           0.94      1022
#    macro avg       0.53      0.51      0.50      1022
# weighted avg       0.90      0.94      0.92      1022
#
# Accuracy Score: 0.9403131115459883
# K-Fold Validation Mean Accuracy: 97.25 %

# %%
model = XGBClassifier(eval_metric='error', learning_rate= 0.1, seed=150,max_depth=2)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       968
#            1       0.38      0.06      0.10        54
#
#     accuracy                           0.95      1022
#    macro avg       0.66      0.53      0.53      1022
# weighted avg       0.92      0.95      0.93      1022
#
# Accuracy Score: 0.9452054794520548
# K-Fold Validation Mean Accuracy: 95.94 %

# %%
model = RandomForestClassifier(criterion='gini', n_estimators= 10, random_state= 0)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       968
#            1       0.11      0.02      0.03        54
#
#     accuracy                           0.94      1022
#    macro avg       0.53      0.51      0.50      1022
# weighted avg       0.90      0.94      0.92      1022
#
# Accuracy Score: 0.9403131115459883
# K-Fold Validation Mean Accuracy: 97.25 %

# %%
model = MLPClassifier(activation='relu', learning_rate_init=0.1, random_state=150, hidden_layer_sizes=(100,))
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
print('Accuracy Score:', accuracy_score(y_test, y_pred))
accuracies = cross_val_score(estimator=model, X=x_train_res, y=y_train_res, cv=10)
print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean() * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       968
#            1       0.12      0.15      0.13        54
#
#     accuracy                           0.90      1022
#    macro avg       0.54      0.54      0.54      1022
# weighted avg       0.91      0.90      0.90      1022
#
# Accuracy Score: 0.8992172211350293
# K-Fold Validation Mean Accuracy: 93.17 %

# %%
##model selection
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(12, input_shape=(15,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train_res, y_train_res, epochs=2, batch_size=10)
# Out:
# Epoch 1/2
# 779/779 [==============================] - 3s 3ms/step - loss: 0.5797 - accuracy: 0.6845
# Epoch 2/2
# 779/779 [==============================] - 3s 3ms/step - loss: 0.4228 - accuracy: 0.8144
